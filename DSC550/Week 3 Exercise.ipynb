# %%
import pandas as pd
from textblob import TextBlob
from sklearn.metrics import accuracy_score

# %% [markdown]
# Part 1: Using the TextBlob Sentiment Analyzer

# %%
#Import the movie review data as a data frame and ensure that the data is loaded properly.
data = pd.read_csv("labeledTrainData.tsv", header=0, \
                    delimiter="\t", quoting=3)

# %%
#Use TextBlob to classify each movie review as positive or negative. Assume that a polarity score greater than or equal to zero 
#is a positive sentiment and less than 0 is a negative sentiment.
def find_polarity(txt):
    blob = TextBlob(txt)
    return blob.sentences[0].sentiment.polarity

# %%
data['polarity'] = data['review'].apply(find_polarity)
data
# Out:
#               id  sentiment  \
# 0       "5814_8"          1
# 1       "2381_9"          1
# 2       "7759_3"          0
# 3       "3630_4"          0
# 4       "9495_8"          1
# ...          ...        ...
# 24995   "3453_3"          0
# 24996   "5064_1"          0
# 24997  "10905_3"          0
# 24998  "10194_3"          0
# 24999   "8478_8"          1
#
#                                                   review  polarity
# 0      "With all this stuff going down at the moment ... -0.107407
# 1      "\"The Classic War of the Worlds\" by Timothy ...  0.356667
# 2      "The film starts with a manager (Nicholas Bell...  0.800000
# 3      "It must be assumed that those who praised thi...  1.000000
# 4      "Superbly trashy and wondrously unpretentious ...  1.000000
# ...                                                  ...       ...
# 24995  "It seems like more consideration has gone int...  0.102083
# 24996  "I don't believe they made this film. Complete...  0.000000
# 24997  "Guy is a loser. Can't get girls, needs to bui...  0.000000
# 24998  "This 30 minute documentary Buñuel made in the...  0.050000
# 24999  "I saw this movie as a child and it broke my h...  0.000000
#
# [25000 rows x 4 columns]

# %%
def find_sentiment(txt):
        if find_polarity(txt) >= 0:
            return 1
        else:
            return 0

# %%
data['textblobsentiments'] = data['review'].apply(find_sentiment)
data
# Out:
#               id  sentiment  \
# 0       "5814_8"          1
# 1       "2381_9"          1
# 2       "7759_3"          0
# 3       "3630_4"          0
# 4       "9495_8"          1
# ...          ...        ...
# 24995   "3453_3"          0
# 24996   "5064_1"          0
# 24997  "10905_3"          0
# 24998  "10194_3"          0
# 24999   "8478_8"          1
#
#                                                   review  polarity  \
# 0      "With all this stuff going down at the moment ... -0.107407
# 1      "\"The Classic War of the Worlds\" by Timothy ...  0.356667
# 2      "The film starts with a manager (Nicholas Bell...  0.800000
# 3      "It must be assumed that those who praised thi...  1.000000
# 4      "Superbly trashy and wondrously unpretentious ...  1.000000
# ...                                                  ...       ...
# 24995  "It seems like more consideration has gone int...  0.102083
# 24996  "I don't believe they made this film. Complete...  0.000000
# 24997  "Guy is a loser. Can't get girls, needs to bui...  0.000000
# 24998  "This 30 minute documentary Buñuel made in the...  0.050000
# 24999  "I saw this movie as a child and it broke my h...  0.000000
#
#        textblobsentiments
# 0                       0
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 24995                   1
# 24996                   1
# 24997                   1
# 24998                   1
# 24999                   1
#
# [25000 rows x 5 columns]

# %% [markdown]
# Positive Reviews: 19,001
# Negative Reviews: 5,982

# %%
#Check the accuracy of this model. Is this model better than random guessing?
accuracy_score(data['sentiment'], data['textblobsentiments'])
# Out:
# 0.60296

# %% [markdown]
# According to this it was 60% accurate, i would say it's more time efficient then random guessing, but 60% isn't that accurate.

# %% [markdown]
# Part 2: Prepping Text for a Custom Model

# %%
import unicodedata
import sys
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
review = data["review"]

# %%
#Convert all text to lowercase letters.
def decapitalizer(string: str) -> str:
    return string.lower()

# %%
noncapital = [decapitalizer(string) for string in review]

# %%
#Remove punctuation and special characters from the text.
punctuation = dict.fromkeys(i for i in range(sys.maxunicode)
    if unicodedata.category(chr(i)).startswith('P'))

# %%
noperiods = [string.translate(punctuation) for string in noncapital]

# %%
#Remove stop words.
stop_words = stopwords.words('english')

# %%
nostopwords = [word for word in noperiods if word not in stop_words]

# %%
#Apply NLTK’s PorterStemmer.
porter = PorterStemmer()

# %%
appliedstemmer = [porter.stem(word) for word in nostopwords]

# %%
#Create a bag-of-words matrix from your stemmed text (output from (4)), where each row is a word-count vector for a single movie
#review (see sections 5.3 & 6.8 in the Machine Learning with Python Cookbook). Display the dimensions of your bag-of-words 
#matrix. The number of rows in this matrix should be the same as the number of rows in your original data frame.
count = CountVectorizer()
bag_of_words = count.fit_transform(appliedstemmer)

# %%
count.get_feature_names()
# Out:
# C:\Users\brand\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '0000000000001',
#  '000001',
#  '00000110',
#  '0001',
#  '00015',
#  '001',
#  '0010',
#  '002',
#  '00383042',
#  '006',
#  '007',
#  '0079',
#  '0080',
#  '0083',
#  '00s',
#  '01',
#  '010',
#  '01000',
#  '010makes',
#  '0110',
#  '012310',
#  '0130',
#  '013007',
#  '02',
#  '029',
#  '03',
#  '0310',
#  '03oct2009',
#  '04',
#  '041',
#  '048',
#  '05',
#  '050',
#  '0510',
#  '053105',
#  '06',
#  '06th',
#  '07',
#  '079',
#  '07kiloton',
#  '08',
#  '081006',
#  '087',
#  '089',
#  '08th',
#  '09',
#  '09082009',
#  '091505',
#  '0f',
#  '0ne',
#  '0r',
#  '0s',
#  '0stars',
#  '0when',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '100000',
#  '1000000',
#  '10000000',
#  '1000000000000',
#  '1000000000000010000000000000',
#  '10002000',
#  '1000lb',
#  '1000s',
#  '1001',
#  '100200',
#  '100am',
#  '100b',
#  '100hell',
#  '100kin',
#  '100m',
#  '100min',
#  '100minute',
#  '100mph',
#  '100percent',
#  '100plus',
#  '100s',
#  '100square',
#  '100th',
#  '100thgrade',
#  '100x',
#  '100yards',
#  '100year',
#  '100yearold',
#  '101',
#  '1010',
#  '1010seek',
#  '1011',
#  '1012',
#  '1013',
#  '1014',
#  '101499',
#  '1015',
#  '101503',
#  '101575',
#  '101706',
#  '101minute',
#  '101st',
#  '101year',
#  '101yearold',
#  '102',
#  '1020',
#  '1020000',
#  '102030',
#  '1025',
#  '102862',
#  '102955',
#  '102nd',
#  '103',
#  '1030',
#  '1030pm',
#  '103104',
#  '1035',
#  '104',
#  '1040',
#  '1040a',
#  '1040s',
#  '105',
#  '1050',
#  '105lbs',
#  '106',
#  '107',
#  '1072000',
#  '1072007',
#  '1075',
#  '108',
#  '109',
#  '1095',
#  '109minute',
#  '10am',
#  '10but',
#  '10check',
#  '10day',
#  '10dirarne',
#  '10dirbrad',
#  '10direwald',
#  '10dirjim',
#  '10dirjohn',
#  '10dirjon',
#  '10dirmichael',
#  '10dirmick',
#  '10dirsteve',
#  '10dirsydney',
#  '10dirtobe',
#  '10foot',
#  '10highly',
#  '10hour',
#  '10i',
#  '10if',
#  '10its',
#  '10just',
#  '10line',
#  '10lines',
#  '10master',
#  '10mil',
#  '10min',
#  '10minute',
#  '10of',
#  '10of10',
#  '10page',
#  '10pm',
#  '10s',
#  '10scale',
#  '10second',
#  '10speed',
#  '10star',
#  '10th',
#  '10the',
#  '10they',
#  '10this',
#  '10times',
#  '10well',
#  '10x',
#  '10x10',
#  '10xs',
#  '10year',
#  '10yearlater',
#  '10yearold',
#  '10yearolds',
#  '10yr',
#  '10yrold',
#  '11',
#  '110',
#  '1100',
#  '11001001',
#  '1100ad',
#  '1100th',
#  '11072004',
#  '110jd',
#  '110minute',
#  '110th',
#  '111',
#  '1110',
#  '111128',
#  '1112009',
#  '111232',
#  '1113',
#  '111but',
#  '111minute',
#  '112',
#  '112001sandler',
#  '112101',
#  '11240',
#  '112413',
#  '112443',
#  '1131516',
#  '1138',
#  '1139',
#  '114',
#  '1146',
#  '115',
#  '115minruntime',
#  '116',
#  '11673',
#  '116th',
#  '117',
#  '1172002',
#  '119',
#  '11m',
#  '11minute',
#  '11th',
#  '11year',
#  '11yearold',
#  '11yearsold',
#  '12',
#  '120',
#  '1200',
#  '12000',
#  '12000000',
#  '12007',
#  '1200f',
#  '1200pm',
#  '1201',
#  '1201pm',
#  '1202',
#  '120page',
#  '12100',
#  '121031',
#  '12106',
#  '1213',
#  '1214',
#  '1215',
#  '121566',
#  '121am',
#  '12242009',
#  '12262008',
#  '12272006',
#  '123',
#  '123000000',
#  '12312006',
#  '12345',
#  '1235',
#  '12383499143743701',
#  '1245am',
#  '125',
#  '125000',
#  '125150',
#  '125m',
#  '1262009',
#  '12638',
#  '127',
#  '1272002',
#  '128',
#  '1282001',
#  '12a',
#  '12episode',
#  '12foot',
#  '12h',
#  '12hour',
#  '12hr',
#  '12m',
#  '12minute',
#  '12mm',
#  '12pack',
#  '12s',
#  '12th',
#  '12th14th',
#  '12thrateat',
#  '12year',
#  '12yearold',
#  '12yearolds',
#  '12years',
#  '12yrold',
#  '13',
#  '130',
#  '1300',
#  '13000',
#  '1300s',
#  '130am',
#  '131',
#  '1314',
#  '1318',
#  '132',
#  '133',
#  '1331',
#  '1335',
#  '1335is',
#  '1336th',
#  '134',
#  '134minute',
#  '135',
#  '13516',
#  '135m',
#  '136',
#  '137',
#  '1371',
#  '138',
#  '138minute',
#  '139',
#  '13and',
#  '13but',
#  '13episode',
#  '13inch',
#  '13k',
#  '13rd',
#  '13s',
#  '13th',
#  '13thclone',
#  '13thi',
#  '13thversions',
#  '13year',
#  '13yearold',
#  '14',
#  '140',
#  '1400',
#  '1408',
#  '140am',
#  '140hp',
#  '140minute',
#  '1410',
#  '1415',
#  '1415yearold',
#  '1416',
#  '1416s',
#  '1417',
#  '142minute',
#  '1430',
#  '145',
#  '1451',
#  '145150',
#  '1454',
#  '146',
#  '147',
#  '1473',
#  '149',
#  '1492',
#  '1498',
#  '1499',
#  '14a',
#  '14goingon9',
#  '14ieme',
#  '14inch',
#  '14minute',
#  '14th',
#  '14x',
#  '14year',
#  '14yearold',
#  '14yearoldgirl',
#  '14yearolds',
#  '14yo',
#  '14yrold',
#  '14ème',
#  '15',
#  '150',
#  '1500',
#  '15000',
#  '150000',
#  '1500000',
#  '15000000',
#  '1500s',
#  '1500sera',
#  '150k',
#  '150m',
#  '150minute',
#  '151',
#  '1510',
#  '1516',
#  '1516yearsold',
#  '1517',
#  '1518',
#  '152',
#  '1520',
#  '153',
#  '154',
#  '1547',
#  '155',
#  '156',
#  '1561',
#  '157',
#  '158',
#  '1594',
#  '1599',
#  '15as',
#  '15bus',
#  '15hr',
#  '15hrs',
#  '15mins',
#  '15minute',
#  '15minutes',
#  '15odd',
#  '15second',
#  '15th',
#  '15thcentury',
#  '15to18',
#  '15year',
#  '15yearold',
#  '15yearolds',
#  '15years',
#  '16',
#  '160',
#  '1600',
#  '16000',
#  '1600s',
#  '160lbs',
#  '160page',
#  '161',
#  '1610',
#  '1617',
#  '1627',
#  '163',
#  '163000',
#  '163minute',
#  '164',
#  '165',
#  '165m',
#  '166',
#  '1660s',
#  '1661',
#  '168',
#  '169',
#  '1692',
#  '1697',
#  '169minute',
#  '16bit',
#  '16ieme',
#  '16k',
#  '16minute',
#  '16mm',
#  '16mmstyle',
#  '16rated',
#  '16s',
#  '16th',
#  '16thcentury',
#  '16x9',
#  '16year',
#  '16yearld',
#  '16yearold',
#  '16yrold',
#  '16ème',
#  '16éme',
#  '17',
#  '170',
#  '1700',
#  '17000',
#  '1700s',
#  '171',
#  '1718',
#  '172003',
#  '175',
#  '177',
#  '1775',
#  '177583',
#  '1780s',
#  '1781',
#  '1790s',
#  '179495',
#  '1798',
#  '17inch',
#  '17million',
#  '17th',
#  '17thcentury',
#  '17year',
#  '17yearold',
#  '18',
#  '180',
#  '1800',
#  '18000',
#  '18000000',
#  '1800makeover',
#  '1800mph',
#  '1800s',
#  '1800smans',
#  '18011844',
#  '1805',
#  '1809',
#  '180d',
#  '1812',
#  '1813',
#  '1814',
#  '1816',
#  '1820',
#  '1820s',
#  '1824',
#  '1825',
#  '183',
#  '1830',
#  '1830s',
#  '1832',
#  '1835',
#  '1836',
#  '1837',
#  '1837this',
#  '1838',
#  '1839',
#  '183minute',
#  '1840',
#  '18401911',
#  '1840s',
#  '1846',
#  '1847',
#  '185',
#  '1850',
#  '1850ies',
#  '1850s',
#  '1851',
#  '1853',
#  '1854',
#  '1855',
#  '1859',
#  '18591860',
#  '1860',
#  '18601909',
#  '18602',
#  '1860s',
#  '1861',
#  '1862',
#  '1863',
#  '1864',
#  '1865',
#  '1870',
#  '1870s',
#  '1871',
#  '1873',
#  '18741965',
#  '1875',
#  '1876',
#  '1880',
#  '1880s',
#  '1881',
#  '1886',
#  '1887',
#  '1888',
#  '1889',
#  '188minute',
#  '188o',
#  '1890',
#  '1890s',
#  '1892',
#  '1893',
#  '1894',
#  '1895',
#  '1896',
#  '18961899',
#  '18961982',
#  '1896jeff',
#  '1897',
#  '1898',
#  '1899',
#  '18a',
#  '18rated',
#  '18th',
#  '18thcentury',
#  '18year',
#  '18yearold',
#  '18yearsold',
#  '19',
#  '190',
#  '1900',
#  '19000000',
#  '1900s',
#  '1901',
#  '1902',
#  '1902ii',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '19061952',
#  '1907',
#  '1908',
#  '1909',
#  '1909s',
#  '1910',
#  '1910s',
#  '1911',
#  '191112',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '19172000',
#  '1918',
#  '191820',
#  '1918it',
#  '1919',
#  '192',
#  '1920',
#  '19201939',
#  '19201998',
#  '1920helping',
#  '1920ies',
#  '1920s',
#  '1920sspring',
#  '1921',
#  '1922',
#  '1922most',
#  '1923',
#  '1924',
#  '19241940',
#  '1924kriemhild',
#  '1925',
#  '1926',
#  '1927',
#  '19271928',
#  '1927s',
#  '1928',
#  '1928s',
#  '1929',
#  '192930',
#  '1929his',
#  '1930',
#  '19301935',
#  '193031',
#  '1930and',
#  '1930comedy',
#  '1930europe',
#  '1930ies',
#  '1930s',
#  '1930sbecause',
#  '1930sera',
#  '1930speter',
#  '1930sset',
#  '1930sstyle',
#  '1930sthis',
#  '1931',
#  '19311942',
#  '193139',
#  '1932',
#  '19323',
#  '193234',
#  '1932s',
#  '1933',
#  '19331939',
#  '19332005',
#  '19334',
#  '1933s',
#  '1933when',
#  '1934',
#  '19341938',
#  '19345',
#  '1934s',
#  '1935',
#  '1935s',
#  '1935very',
#  '1936',
#  '19361945',
#  '19361946',
#  '193637',
#  '1936in',
#  '1937',
#  '1937s',
#  '1938',
#  '19381981',
#  '1938s',
#  '1939',
#  '19391942',
#  '193940',
#  '193945',
#  '1939i',
#  '1939in',
#  '1939may',
#  '1939out',
#  '1939s',
#  '193os',
#  '194',
#  '1940',
#  '19401941',
#  '19401943',
#  '19401944',
#  '194041',
#  '1940by',
#  '1940just',
#  '1940may',
#  '1940s',
#  '1940s1950sranging',
#  '1940s50s',
#  '1940s60s',
#  '1940sbut',
#  '1940the',
#  '1941',
#  '19411943',
#  '19411945',
#  '19411991',
#  '1941s',
#  '1942',
#  '1942era',
#  '1942february',
#  '1942july',
#  '1943',
#  '1944',
#  '194445',
#  '1944s',
#  '1944the',
#  '1945',
#  '19452000',
#  '1945film',
#  '1946',
#  '19461949',
#  '194666',
#  '1947',
#  '19471948',
#  '194748',
#  '1947i',
#  '1947s',
#  '1948',
#  '1948s',
#  '1949',
#  '194950',
#  '1949er',
#  '1949s',
#  '195',
#  '1950',
#  '195051',
#  '1950of',
#  '1950s',
#  '1950s1960s',
#  '1950s60s',
#  '1950sbefore',
#  '1950sesque',
#  '1950sfaithful',
#  '1950sness',
#  '1950sprinceton',
#  '1950sstyle',
#  '1950sstyled',
#  '1950stewart',
#  '1950version',
#  '1951',
#  '19512001',
#  '1952',
#  '19522002',
#  '195255',
#  '1953',
#  '195354',
#  '19537',
#  '1953i',
#  '1953s',
#  '1954',
#  '1954all',
#  '1955',
#  '195519561957',
#  '19551965',
#  '195556',
#  '195559',
#  '195564',
#  '1955s',
#  '1956',
#  '1956and',
#  '1956s',
#  '1956title',
#  '1957',
#  '19571963',
#  '1957s',
#  '1958',
#  '1958and',
#  '1958stands',
#  '1958titanic',
#  '1959',
#  '19591965',
#  '19591973',
#  '195960',
#  '1959s',
#  '1960',
#  '19601980',
#  '1960hardly',
#  '1960s',
#  '1960s1970s',
#  '1960s70s',
#  '1960searly',
#  '1960sstyle',
#  '1960sthats',
#  '1960sunderwear',
#  '1960there',
#  '1961',
#  '1961s',
#  '1962',
#  '1962s',
#  '1963',
#  '19631989',
#  '1963the',
#  '1964',
#  '19641968',
#  '196468',
#  '1965',
#  '1965s',
#  '1966',
#  '1966s',
#  '1966sons',
#  '1967',
#  '19671973',
#  '1967has',
#  '1967s',
#  '1968',
#  '196819',
#  '19681988',
#  '196877',
#  '1968type',
#  '1969',
#  '19691972',
#  '196970',
#  '196974',
#  '1969s',
#  '1969starring',
#  '1969the',
#  '197',
#  '1970',
#  '1970ies',
#  '1970s',
#  '1970s80s',
#  '1970sand',
#  '1970searly',
#  '1970si',
#  '1970sincluding',
#  '1970sitalian',
#  '1970sstyle',
#  '1970years',
#  '1971',
#  '1972',
#  '197273',
#  '1972i',
#  '1972s',
#  '1973',
#  '197376',
#  '1973s',
#  '1973watching',
#  '1974',
#  '19741979',
#  '19741980',
#  '19745',
#  '1974a',
#  '1974groundbreaker',
#  '1974s',
#  '1974safari',
#  '1975',
#  '197583',
#  '1975s',
#  '1976',
#  '19761984',
#  '197677',
#  '1976s',
#  '1977',
#  '19772006',
#  '1977s',
#  '1978',
#  '19781979',
#  '197879',
#  '197892',
#  '1978on',
#  '1978s',
#  '1979',
#  '19796',
#  '197982',
#  '1979is',
#  '1979s',
#  '197o',
#  '198',
#  '1980',
#  '1980i',
#  '1980ies',
#  '1980if',
#  '1980s',
#  '1980sat',
#  '1980sboom',
#  '1980si',
#  '1981',
#  '198182',
#  '1981i',
#  '1981s',
#  '1982',
#  '19821951',
#  '198283',
#  '1982et',
#  '1982in',
#  '1982s',
#  '1983',
#  '198385',
#  '1983back',
#  '1983i',
#  '1983s',
#  '1984',
#  '19841985',
#  '1984critters',
#  '1984i',
#  '1984ish',
#  '1984while',
#  '1985',
#  '1985most',
#  '1986',
#  '1986onward',
#  '1986s',
#  '1986wannabe',
#  '1987',
#  '1987all',
#  '1987not',
#  '1987s',
#  '1988',
#  '198889',
#  '1988mostly',
#  '1988of',
#  '1988s',
#  '1989',
#  '1989s',
#  '199',
#  '1990',
#  '1990a',
#  '1990really',
#  '1990s',
#  '1990smore',
#  '1990sstyle',
#  '1991',
#  '1991s',
#  '1992',
#  '1992and',
#  '1992s',
#  '1993',
#  '19934',
#  '199399',
#  '1993it',
#  '1993s',
#  '1994',
#  '19941997',
#  '19942004',
#  '1994s',
#  '1995',
#  '199596',
#  '1995i',
#  '1995s',
#  '1996',
#  '19961997',
#  '19961999',
#  '1996behind',
#  '1996s',
#  '1996screen',
#  '1996style',
#  '1997',
#  '1997and',
#  '1997natali',
#  '1997s',
#  '1997so',
#  '1998',
#  '1998era',
#  '1998s',
#  '1999',
#  '19992000',
#  '19992007',
#  '1999999',
#  '1999it',
#  '1999s',
#  '19did',
#  '19k',
#  '19minute',
#  '19month',
#  '19th',
#  '19thc',
#  '19thcentury',
#  '19thearly',
#  '19yearold',
#  '1am',
#  '1and',
#  '1awful',
#  '1awfulnot',
#  '1billy',
#  '1d',
#  '1day',
#  '1dimensional',
#  '1dimentional',
#  '1do',
#  '1does',
#  '1elisha',
#  '1from',
#  '1h',
#  '1h30',
#  '1h40',
#  '1h40m',
#  '1h53',
#  '1hour',
#  '1howeverbut',
#  '1hr',
#  '1in1000',
#  '1it',
#  '1its',
#  '1jesus',
#  '1million',
#  '1min',
#  '1mln',
#  ...]

# %%
#Create a term frequency-inverse document frequency (tf-idf) matrix from your stemmed text, for your movie reviews 
#(see section 6.9 in the Machine Learning with Python Cookbook). Display the dimensions of your tf-idf matrix. These dimensions 
#should be the same as your bag-of-words matrix.
tfidf = TfidfVectorizer()
feature_matrix = tfidf.fit_transfrom(appliedstemmer)

# %%
tfidf.vocabulary_
# Out:
# {'with': 110216,
#  'all': 4694,
#  'this': 100105,
#  'stuff': 95933,
#  'going': 41889,
#  'down': 29564,
#  'at': 7957,
#  'the': 99556,
#  'moment': 64914,
#  'mj': 64627,
#  'ive': 52172,
#  'started': 94555,
#  'listening': 58227,
#  'to': 101158,
#  'his': 46831,
#  'music': 66781,
#  'watching': 108290,
#  'odd': 70365,
#  'documentary': 28825,
#  'here': 46003,
#  'and': 5684,
#  'there': 99794,
#  'watched': 108278,
#  'wiz': 110297,
#  'moonwalker': 65284,
#  'again': 3914,
#  'maybe': 62006,
#  'just': 53645,
#  'want': 107977,
#  'get': 40959,
#  'certain': 17597,
#  'insight': 50746,
#  'into': 51302,
#  'guy': 43743,
#  'who': 109555,
#  'thought': 100261,
#  'was': 108169,
#  'really': 81330,
#  'cool': 22292,
#  'in': 49724,
#  'eighties': 31523,
#  'make': 60429,
#  'up': 105585,
#  'my': 66968,
#  'mind': 63926,
#  'whether': 109359,
#  'he': 45328,
#  'is': 51712,
#  'guilty': 43514,
#  'or': 71563,
#  'innocent': 50633,
#  'part': 73602,
#  'biography': 11819,
#  'feature': 36022,
#  'film': 36669,
#  'which': 109365,
#  'remember': 82571,
#  'see': 87873,
#  'cinema': 19187,
#  'when': 109331,
#  'it': 51922,
#  'originally': 71738,
#  'released': 82409,
#  'some': 92655,
#  'of': 70436,
#  'has': 45039,
#  'subtle': 96325,
#  'messages': 63201,
#  'about': 2537,
#  'mjs': 64630,
#  'feeling': 36093,
#  'towards': 101910,
#  'press': 78048,
#  'also': 5068,
#  'obvious': 70240,
#  'message': 63195,
#  'drugs': 30173,
#  'are': 7084,
#  'bad': 9061,
#  'mkay': 64634,
#  'br': 13756,
#  'visually': 107291,
#  'impressive': 49659,
#  'but': 15447,
#  'course': 22948,
#  'michael': 63444,
#  'jackson': 52274,
#  'so': 92282,
#  'unless': 105017,
#  'you': 111895,
#  'remotely': 82630,
#  'like': 57854,
#  'anyway': 6554,
#  'then': 99698,
#  'hate': 45106,
#  'find': 37019,
#  'boring': 13390,
#  'may': 61998,
#  'call': 15912,
#  'an': 5583,
#  'egotist': 31468,
#  'for': 38169,
#  'consenting': 21768,
#  'making': 60478,
#  'movie': 65891,
#  'most': 65631,
#  'fans': 35425,
#  'would': 110912,
#  'say': 86528,
#  'that': 99493,
#  'made': 60068,
#  'if': 49081,
#  'true': 102932,
#  'nice': 68312,
#  'him': 46640,
#  'actual': 3277,
#  'bit': 11926,
#  'finally': 36999,
#  'starts': 94576,
#  'only': 71271,
#  'on': 70992,
#  '20': 1030,
#  'minutes': 64168,
#  'excluding': 34134,
#  'smooth': 91994,
#  'criminal': 23615,
#  'sequence': 88679,
#  'joe': 53105,
#  'pesci': 74971,
#  'convincing': 22239,
#  'as': 7581,
#  'psychopathic': 79299,
#  'powerful': 77470,
#  'drug': 30149,
#  'lord': 58937,
#  'why': 109662,
#  'wants': 107992,
#  'dead': 25341,
#  'beyond': 11441,
#  'me': 62379,
#  'because': 10453,
#  'overheard': 72460,
#  'plans': 76011,
#  'nah': 67174,
#  'pescis': 74972,
#  'character': 17922,
#  'ranted': 80784,
#  'wanted': 107982,
#  'people': 74461,
#  'know': 55181,
#  'supplying': 97049,
#  'etc': 33481,
#  'dunno': 30557,
#  'hates': 45119,
#  'lots': 59036,
#  'things': 99972,
#  'turning': 103273,
#  'car': 16452,
#  'robot': 84333,
#  'whole': 109581,
#  'speed': 93483,
#  'demon': 26282,
#  'director': 27791,
#  'must': 66872,
#  'have': 45191,
#  'had': 43939,
#  'patience': 73896,
#  'saint': 85780,
#  'came': 16003,
#  'filming': 36776,
#  'kiddy': 54584,
#  'usually': 105910,
#  'directors': 27823,
#  'working': 110709,
#  'one': 71053,
#  'kid': 54563,
#  'let': 57389,
#  'alone': 4983,
#  'bunch': 15138,
#  'them': 99617,
#  'performing': 74681,
#  'complex': 21175,
#  'dance': 24817,
#  'scene': 86771,
#  'bottom': 13523,
#  'line': 58041,
#  'level': 57449,
#  'another': 6131,
#  'think': 100003,
#  'not': 69398,
#  'stay': 94684,
#  'away': 8649,
#  'does': 28892,
#  'try': 103020,
#  'give': 41432,
#  'off': 70449,
#  'wholesome': 109594,
#  'ironically': 51623,
#  'bestest': 11251,
#  'buddy': 14861,
#  'girl': 41303,
#  'truly': 102970,
#  'talented': 98139,
#  'ever': 33724,
#  'grace': 42499,
#  'planet': 75988,
#  'well': 108790,
#  'attention': 8143,
#  'gave': 40446,
#  'subjecthmmm': 96166,
#  'dont': 29196,
#  'can': 16136,
#  'be': 10249,
#  'different': 27455,
#  'behind': 10723,
#  'closed': 19880,
#  'doors': 29273,
#  'fact': 35029,
#  'either': 31579,
#  'extremely': 34765,
#  'stupid': 96000,
#  'sickest': 90429,
#  'liars': 57557,
#  'hope': 47564,
#  'latt': 56499,
#  'classic': 19518,
#  'war': 107997,
#  'worlds': 110794,
#  'by': 15596,
#  'timothy': 100953,
#  'hines': 46741,
#  'very': 106674,
#  'entertaining': 32808,
#  'obviously': 70243,
#  'goes': 41857,
#  'great': 42820,
#  'effort': 31405,
#  'lengths': 57192,
#  'faithfully': 35176,
#  'recreate': 81733,
#  'wells': 108979,
#  'book': 13173,
#  'mr': 66232,
#  'succeeds': 96370,
#  'doing': 28982,
#  'those': 100240,
#  'appreciated': 6859,
#  'standard': 94373,
#  'predictable': 77738,
#  'hollywood': 47218,
#  'fare': 35550,
#  'comes': 20771,
#  'out': 72021,
#  'every': 33810,
#  'year': 111593,
#  'eg': 31419,
#  'spielberg': 93596,
#  'version': 106636,
#  'tom': 101344,
#  'cruise': 23966,
#  'slightest': 91604,
#  'resemblance': 83037,
#  'everyone': 33823,
#  'looks': 58848,
#  'envision': 32964,
#  'themselves': 99670,
#  'amateur': 5241,
#  'critics': 23723,
#  'look': 58815,
#  'criticize': 23718,
#  'everything': 33834,
#  'they': 99874,
#  'others': 71939,
#  'rate': 80944,
#  'more': 65380,
#  'important': 49599,
#  'baseslike': 9949,
#  'being': 10749,
#  'entertained': 32801,
#  'never': 68119,
#  'agree': 4113,
#  'we': 108505,
#  'enjoyed': 32641,
#  'put': 79742,
#  'faithful': 35175,
#  'hg': 46300,
#  'novel': 69625,
#  'found': 38565,
#  'easy': 31040,
#  'overlook': 72508,
#  'what': 109233,
#  'perceive': 74551,
#  'its': 52073,
#  'shortcom': 90021,
#  'manager': 60683,
#  'nicholas': 68344,
#  'bell': 10854,
#  'giving': 41444,
#  'welcome': 108773,
#  'investors': 51465,
#  'robert': 84308,
#  'carradine': 16746,
#  'primal': 78242,
#  'park': 73510,
#  'secret': 87784,
#  'project': 78674,
#  'mutating': 66911,
#  'animal': 5933,
#  'using': 105881,
#  'fossilized': 38536,
#  'dna': 28740,
#  'jurassik': 53626,
#  'scientists': 87148,
#  'resurrect': 83289,
#  'natures': 67515,
#  'fearsome': 35999,
#  'predators': 77716,
#  'sabretooth': 85561,
#  'tiger': 100670,
#  'smilodon': 91931,
#  'scientific': 87137,
#  'ambition': 5317,
#  'turns': 103288,
#  'deadly': 25381,
#  'however': 48079,
#  'high': 46397,
#  'voltage': 107458,
#  'fence': 36225,
#  'opened': 71390,
#  'creature': 23410,
#  'escape': 33299,
#  'begins': 10680,
#  'savagely': 86455,
#  'stalking': 94333,
#  'prey': 78179,
#  'human': 48339,
#  'visitors': 107270,
#  'tourists': 101886,
#  'scientificmeanwhile': 87139,
#  'youngsters': 111960,
#  'enter': 32788,
#  'restricted': 83251,
#  'area': 7085,
#  'security': 87837,
#  'center': 17537,
#  'attacked': 8099,
#  'pack': 72871,
#  'large': 56273,
#  'prehistorical': 77836,
#  'animals': 5944,
#  'deadlier': 25375,
#  'bigger': 11630,
#  'addition': 3362,
#  'agent': 4000,
#  'stacy': 94219,
#  'haiduk': 44024,
#  'her': 45970,
#  'mate': 61755,
#  'brian': 14173,
#  'wimmer': 109944,
#  'fight': 36575,
#  'hardly': 44812,
#  'against': 3948,
#  'carnivorous': 16696,
#  'smilodons': 91932,
#  'sabretooths': 85564,
#  'real': 81251,
#  'star': 94442,
#  'stars': 94526,
#  'astounding': 7905,
#  'terrifyingly': 99270,
#  'though': 100246,
#  'giant': 41107,
#  'group': 43247,
#  'run': 85294,
#  'afoul': 3834,
#  'furthermore': 39708,
#  'third': 100056,
#  'dangerous': 24879,
#  'slow': 91722,
#  'stalks': 94337,
#  'victims': 106815,
#  'delivers': 26164,
#  'goods': 42140,
#  'blood': 12448,
#  'gore': 42261,
#  'beheading': 10716,
#  'hairraising': 44073,
#  'chillsfull': 18678,
#  'scares': 86678,
#  'appear': 6758,
#  'mediocre': 62586,
#  'special': 93387,
#  'effectsthe': 31377,
#  'story': 95329,
#  'provides': 79037,
#  'exciting': 34112,
#  'stirring': 95114,
#  'entertainment': 32824,
#  'results': 83274,
#  'quite': 80215,
#  'majority': 60420,
#  'computer': 21273,
#  'generator': 40661,
#  'seem': 87916,
#  'totally': 101774,
#  'lousy': 59114,
#  'middling': 63598,
#  'performances': 74655,
#  'players': 76110,
#  'reacting': 81185,
#  'appropriately': 6891,
#  'becoming': 10490,
#  'foodactors': 38091,
#  'vigorously': 106990,
#  'physical': 75358,
#  'dodging': 28873,
#  'beasts': 10337,
#  'runningbound': 85325,
#  'leaps': 56833,
#  'dangling': 24889,
#  'over': 72293,
#  'walls': 107889,
#  'packs': 72885,
#  'ridiculous': 83856,
#  'final': 36984,
#  'no': 68686,
#  'small': 91835,
#  'kids': 54611,
#  'realisticgory': 81276,
#  'violent': 107150,
#  'attack': 8098,
#  'scenes': 86804,
#  'other': 71929,
#  'films': 36846,
#  'following': 38041,
#  'sabretooth2002': 85562,
#  'james': 52389,
#  'hickox': 46347,
#  'vanessa': 106241,
#  'angel': 5826,
#  'david': 25186,
#  'keith': 54280,
#  'john': 53148,
#  'rhys': 83704,
#  'davies': 25196,
#  'much': 66322,
#  'better': 11338,
#  '10000': 59,
#  'bc2006': 10229,
#  'roland': 84523,
#  'emmerich': 32131,
#  'steven': 94932,
#  'strait': 95502,
#  'cliff': 19749,
#  'curtis': 24365,
#  'camilla': 16054,
#  'belle': 10862,
#  'motion': 65708,
#  'picture': 75458,
#  'filled': 36649,
#  'bloody': 12517,
#  'moments': 64923,
#  'badly': 9133,
#  'directed': 27751,
#  'george': 40831,
#  'miller': 63843,
#  'originality': 71733,
#  'takes': 98106,
#  'too': 101469,
#  'many': 61030,
#  'elements': 31732,
#  'from': 39285,
#  'previous': 78170,
#  'australian': 8372,
#  'television': 98951,
#  'tidal': 100631,
#  'wave': 108399,
#  'journey': 53347,
#  'earth': 30960,
#  'occasionally': 70262,
#  'man': 60674,
#  'snowy': 92254,
#  'river': 84174,
#  'zeus': 112340,
#  'roxannerobinson': 85065,
#  'crusoe': 24013,
#  'rating': 80962,
#  'below': 10905,
#  'average': 8542,
#  'barrel': 9829,
#  'assumed': 7864,
#  'praised': 77569,
#  'greatest': 42833,
#  'filmed': 36726,
#  'opera': 71419,
#  'didnt': 27378,
#  'read': 81202,
#  'somewhere': 92737,
#  'care': 16526,
#  'wagner': 107695,
#  'anything': 6543,
#  'except': 34067,
#  'their': 99608,
#  'desire': 26753,
#  'cultured': 24223,
#  'representation': 82893,
#  'wagners': 107698,
#  'swansong': 97434,
#  'strikes': 95714,
#  'unmitigated': 105088,
#  'disaster': 27977,
#  'leaden': 56775,
#  'reading': 81216,
#  'score': 87221,
#  'matched': 61741,
#  'tricksy': 102651,
#  'lugubrious': 59513,
#  'realisation': 81263,
#  'text': 99419,
#  'questionable': 80079,
#  'ideas': 48981,
#  'matter': 61872,
#  'play': 76088,
#  'especially': 33365,
#  'shakespeare': 89232,
#  'should': 90094,
#  'allowed': 4847,
#  'anywhere': 6577,
#  'near': 67642,
#  'theatre': 99578,
#  'studio': 95912,
#  'syberberg': 97703,
#  'fashionably': 35688,
#  'without': 110252,
#  'smallest': 91842,
#  'justification': 53666,
#  'decided': 25663,
#  'parsifal': 73592,
#  'bisexual': 11905,
#  'integration': 50952,
#  'title': 101089,
#  'latter': 56502,
#  'stages': 94258,
#  'transmutes': 102269,
#  'kind': 54777,
#  'beatnik': 10364,
#  'babe': 8851,
#  'continues': 22061,
#  'sing': 90850,
#  'tenor': 99116,
#  'few': 36404,
#  'any': 6506,
#  'actors': 3196,
#  'singers': 90867,
#  'double': 29436,
#  'dose': 29397,
#  'armin': 7255,
#  'jordan': 53284,
#  'conductor': 21492,
#  'seen': 87933,
#  'face': 34970,
#  'heard': 45448,
#  'voice': 107398,
#  'amfortas': 5430,
#  'appears': 6773,
#  'monstrously': 65161,
#  'exposure': 34591,
#  'batonzilla': 10102,
#  'ate': 7972,
#  'monsalvat': 65119,
#  'during': 30628,
#  'playing': 76126,
#  'good': 42048,
#  'friday': 39111,
#  'way': 108425,
#  'transcendant': 102184,
#  'loveliness': 59189,
#  'nature': 67509,
#  'represented': 82898,
#  'scattering': 86747,
#  'shopworn': 90000,
#  'flaccid': 37381,
#  'crocuses': 23774,
#  'stuck': 95878,
#  'illlaid': 49214,
#  'turf': 103234,
#  'expedient': 34415,
#  'baffles': 9204,
#  'sometimes': 92715,
#  'piece': 75498,
#  'such': 96412,
#  'imperfections': 49519,
#  'our': 72008,
#  'thoughts': 100287,
#  'cant': 16291,
#  'couldnt': 22789,
#  'splice': 93755,
#  'gurnemanz': 43687,
#  'mountain': 65786,
#  'pasture': 73830,
#  'lush': 59656,
#  'provided': 79032,
#  'julie': 53521,
#  'andrews': 5765,
#  'sound': 93043,
#  'hard': 44756,
#  'endure': 32468,
#  'voices': 107411,
#  'trumpets': 102983,
#  'particular': 73645,
#  'possessing': 77162,
#  'aural': 8338,
#  'glare': 41506,
#  'adds': 3378,
#  'sort': 92968,
#  'fatigue': 35829,
#  'impatience': 49497,
#  'uninspired': 104896,
#  'conducting': 21491,
#  'paralytic': 73379,
#  'unfolding': 104728,
#  'ritual': 84151,
#  'someone': 92670,
#  'review': 83523,
#  'mentioned': 63002,
#  '1951': 742,
#  'bayreuth': 10191,
#  'recording': 81712,
#  'knappertsbusch': 55088,
#  'tempi': 99010,
#  'often': 70621,
#  'altogether': 5150,
#  'lacks': 55837,
#  'sense': 88542,
#  'pulse': 79478,
#  'ebb': 31082,
#  'flow': 37830,
#  'after': 3865,
#  'half': 44113,
#  'century': 17570,
#  'orchestral': 71612,
#  'set': 88872,
#  'modern': 64746,
#  'pressings': 78057,
#  'still': 95024,
#  'superior': 96899,
#  'superbly': 96807,
#  'trashy': 102359,
#  'wondrously': 110506,
#  'unpretentious': 105191,
#  '80s': 2120,
#  'exploitation': 34519,
#  'hooray': 47539,
#  'precredits': 77704,
#  'opening': 71399,
#  'sequences': 88686,
#  'somewhat': 92729,
#  'false': 35255,
#  'impression': 49650,
#  'were': 109073,
#  'dealing': 25415,
#  'serious': 88787,
#  'harrowing': 44986,
#  'drama': 29757,
#  'need': 67783,
#  'fear': 35975,
#  'barely': 9725,
#  'ten': 99046,
#  'later': 56436,
#  'until': 105477,
#  'necks': 67756,
#  'nonsensical': 69155,
#  'chainsaw': 17700,
#  'battles': 10135,
#  'rough': 84961,
#  'fistfights': 37282,
#  'lurid': 59644,
#  'dialogs': 27219,
#  'gratuitous': 42746,
#  'nudity': 69809,
#  'bo': 12698,
#  'ingrid': 50491,
#  'two': 103548,
#  'orphaned': 71801,
#  'siblings': 90409,
#  'unusually': 105523,
#  'close': 19878,
#  'even': 33680,
#  'slightly': 91606,
#  'perverted': 74958,
#  'relationship': 82369,
#  'imagine': 49324,
#  'playfully': 76117,
#  'ripping': 84085,
#  'towel': 101913,
#  'covers': 23031,
#  'your': 111967,
#  'sisters': 91018,
#  'naked': 67227,
#  'body': 12799,
#  'stare': 94465,
#  'unshaven': 105370,
#  'genitals': 40700,
#  'several': 88962,
#  'sister': 91007,
#  'judging': 53462,
#  'dubbed': 30267,
#  'laughter': 56582,
#  'she': 89492,
#  'doesnt': 28901,
#  'sick': 90420,
#  'dude': 30339,
#  'fled': 37573,
#  'russia': 85388,
#  'parents': 73469,
#  'nasty': 67428,
#  'soldiers': 92558,
#  'brutally': 14718,
#  'slaughtered': 91444,
#  'mommy': 64943,
#  'daddy': 24605,
#  'friendly': 39153,
#  'smuggler': 92022,
#  'took': 101494,
#  'custody': 24411,
#  'raised': 80558,
#  'trained': 102109,
#  'expert': 34471,
#  'smugglers': 92023,
#  'plot': 76270,
#  'lifts': 57782,
#  'years': 111627,
#  'theyre': 99882,
#  'facing': 35026,
#  'ultimate': 103890,
#  'quest': 80076,
#  'mythical': 67070,
#  'incredibly': 50002,
#  'valuable': 106144,
#  'white': 109474,
#  'fire': 37126,
#  'diamond': 27255,
#  'coincidentally': 20353,
#  'mine': 64000,
#  'life': 57673,
#  'little': 58303,
#  'narrative': 67371,
#  'structure': 95822,
#  'sure': 97111,
#  'lot': 59021,
#  'fun': 39529,
#  'watch': 108264,
#  'time': 100759,
#  'clue': 19992,
#  'whos': 109647,
#  'beating': 10352,
#  'cause': 17294,
#  'bet': 11296,
#  'understood': 104487,
#  'less': 57327,
#  'whatever': 109240,
#  'violence': 107133,
#  'magnificently': 60265,
#  'grotesque': 43214,
#  'single': 90888,
#  'twist': 103516,
#  'pleasingly': 76206,
#  'retarded': 83318,
#  'script': 87461,
#  'bonkers': 13103,
#  'repair': 82776,
#  'suddenly': 96460,
#  'wont': 110516,
#  'reveal': 83448,
#  'reason': 81410,
#  'needs': 67803,
#  'replacement': 82834,
#  'fred': 38909,
#  'williamson': 109890,
#  'enters': 32799,
#  'big': 11601,
#  'cigar': 19144,
#  'mouth': 65840,
#  'sleazy': 91503,
#  'black': 12022,
#  'fingers': 37072,
#  'local': 58490,
#  'prostitutes': 78932,
#  'bos': 13450,
#  'principal': 78283,
#  'opponent': 71490,
#  'italian': 51931,
#  'chick': 18539,
#  'breasts': 14058,
#  'hideous': 46370,
#  'accent': 2719,
#  'preposterous': 77948,
#  'catchy': 17165,
#  'theme': 99631,
#  'song': 92777,
#  'plays': 76141,
#  'least': 56857,
#  'dozen': 29669,
#  'times': 100856,
#  'throughout': 100461,
#  'theres': 99827,
#  'obligatory': 70120,
#  'werefallinginlove': 109081,
#  'montage': 65163,
#  'loads': 58449,
#  'attractions': 8192,
#  'god': 41772,
#  'brilliant': 14291,
#  'experience': 34444,
#  'original': 71726,
#  'french': 39013,
#  'translates': 102247,
#  'itself': 52077,
#  'survive': 97244,
#  'uniquely': 104939,
#  'appropriate': 6888,
#  'makes': 60456,
#  'rest': 83207,
#  'non': 68840,
#  'got': 42369,
#  'pretty': 78139,
#  'action': 3068,
#  'change': 17823,
#  'location': 58511,
#  'harry': 44991,
#  'hurt': 48600,
#  'offensive': 70486,
#  'eastwood': 31034,
#  'form': 38365,
#  'dirty': 27890,
#  'liked': 57865,
#  'pat': 73835,
#  'hingle': 46746,
#  'town': 101925,
#  'cop': 22358,
#  'than': 99459,
#  'pool': 76852,
#  '45': 1634,
#  'could': 22782,
#  'been': 10563,
#  'short': 90006,
#  'cheesy': 18351,
#  'effects': 31352,
#  'soso': 92991,
#  'acting': 3009,
#  'looked': 58826,
#  'past': 73797,
#  'wasnt': 108215,
#  'background': 8969,
#  'centers': 17547,
#  'around': 7335,
#  'evil': 33879,
#  'druid': 30182,
#  'witch': 110185,
#  'linked': 58110,
#  'woman': 110404,
#  'gets': 40969,
#  'migraines': 63696,
#  'drags': 29739,
#  'clearly': 19641,
#  'explains': 34493,
#  'keeps': 54250,
#  'plodding': 76261,
#  'christopher': 18986,
#  'walken': 107819,
#  'completely': 21157,
#  'senseless': 88550,
#  'potential': 77362,
#  'tv': 103356,
#  'avoid': 8587,
#  'movi': 65890,
#  'video': 106851,
#  'friends': 39161,
#  'house': 47988,
#  'im': 49291,
#  'glad': 41461,
#  'did': 27357,
#  'waste': 108230,
#  'money': 64990,
#  'buying': 15555,
#  'cover': 23021,
#  '1975': 848,
#  'capricorn': 16407,
#  'clips': 19824,
#  'rocket': 84383,
#  'blowups': 12579,
#  'related': 82363,
#  'manned': 60905,
#  'flight': 37666,
#  'sibrels': 90411,
#  'smoking': 91979,
#  'gun': 43595,
#  'clip': 19816,
#  'astronauts': 7928,
#  'preparing': 77938,
#  'broadcast': 14409,
#  'edits': 31260,
#  'own': 72757,
#  'voiceover': 107408,
#  'instead': 50845,
#  'letting': 57429,
#  'us': 105813,
#  'listen': 58220,
#  'crew': 23545,
#  'curiously': 24306,
#  'ends': 32447,
#  'showing': 90182,
#  'zapruder': 112198,
#  'claims': 19420,
#  'radiation': 80391,
#  'shielding': 89698,
#  'photography': 75316,
#  'lead': 56771,
#  'believe': 10828,
#  'ignorant': 49116,
#  'ax': 8742,
#  'grind': 43081,
#  'nasa': 67396,
#  'american': 5383,
#  'general': 40632,
#  'science': 87127,
#  'friend': 39138,
#  'bought': 13541,
#  'grossly': 43205,
#  'overpriced': 72575,
#  'despite': 26816,
#  'featuring': 36038,
#  'names': 67262,
#  'adam': 3312,
#  'sandler': 86074,
#  'billy': 11752,
#  'bob': 12739,
#  'thornton': 100222,
#  'burt': 15321,
#  'young': 111933,
#  'funny': 39612,
#  'taking': 98112,
#  'chisel': 18751,
#  'hammering': 44395,
#  'straight': 95456,
#  'through': 100448,
#  'earhole': 30897,
#  'uses': 105870,
#  'tired': 101037,
#  'comedic': 20699,
#  'techniques': 98754,
#  'consistently': 21820,
#  'breaking': 14028,
#  'fourth': 38614,
#  'wall': 107851,
#  'talks': 98202,
#  'audience': 8245,
#  'seemingly': 87924,
#  'pointless': 76545,
#  'montages': 65164,
#  'hot': 47886,
#  'girls': 41368,
#  'waiter': 107748,
#  'ship': 89779,
#  'successful': 96377,
#  'comedian': 20693,
#  'order': 71631,
#  'become': 10483,
#  'women': 110445,
#  'ships': 89802,
#  'resident': 83085,
#  'shamelessly': 89296,
#  'named': 67248,
#  'dickie': 27325,
#  'due': 30357,
#  'unfathomable': 104694,
#  'success': 96375,
#  'opposite': 71509,
#  'gender': 40612,
#  'presumed': 78087,
#  'lost': 59005,
#  'sea': 87599,
#  'sandlers': 86077,
#  'shecker': 89511,
#  'break': 14011,
#  'hes': 46213,
#  'rather': 80958,
#  'locked': 58523,
#  'bathroom': 10075,
#  'presumably': 78084,
#  'perhaps': 74691,
#  'vomited': 107483,
#  'worst': 110879,
#  'tim': 100742,
#  'full': 39459,
#  'references': 81998,
#  'mad': 60036,
#  'max': 61974,
#  'ii': 49132,
#  ...}
